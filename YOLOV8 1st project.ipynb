# %%
# %pip install roboflow
# %pip install torch
# %pip install opencv-python
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 425.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 24.4 MB/s eta 0:00:00
# ...

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from ultralytics import YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="MilO0iLLGKAfLjnTqUi4")
project = rf.workspace("roboflow-100").project("animals-ij5d2")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.90, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to animals-2 in yolov8:: 100%|██████████| 2012/2012 [00:00<00:00, 11052.33it/s]

# %%
model = YOLO('yolov10n.pt')
# Out:
# ...
# 100%|██████████| 5.59M/5.59M [00:00<00:00, 96.1MB/s]

# %%
import zipfile
import os

# Define the path to the ZIP file and the extraction directory
zip_file_path = '/content/animals.v2-release.yolov8 (1).zip'
extract_dir = '/content/animals.v2-release.yolov8 (1)_files'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print("Extraction complete!")
# Out:
# Extraction complete!

# %%
training = '/content/animals.v2-release.yolov8 (1)_files/train'
testing = '/content/animals.v2-release.yolov8 (1)_files/test'
val = '/content/animals.v2-release.yolov8 (1)_files/valid'

# %%
model = YOLO('yolov10n.pt')

# %%
model.train(data='/content/animals.v2-release.yolov8 (1)_files/data.yaml', epochs=10, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2,698,316 parameters, 0 gradients, 8.2 GFLOPs
# val: Scanning /content/animals.v2-release.yolov8 (1)_files/valid/labels.cache... 200 images, 0 backgrounds, 0 corrupt: 100%|██████████| 200/200 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:05<00:00,  2.58it/s]
#                    all        200        351        0.6      0.539      0.606      0.467
#                    cat         18         18      0.533      0.611       0.63      0.477
#                chicken         18         51      0.634      0.549      0.579       0.39
#                    cow         23         51      0.482      0.431      0.472      0.356
# ...

# %%
import os
import cv2 as cv

results = model('/content/animals.v2-release.yolov8 (1)_files/train/images/100_jpg.rf.74b204ede0834a099f56a41742941027.jpg')
results[0].plot()
# Out:
# image 1/1 /content/animals.v2-release.yolov8 (1)_files/train/images/100_jpg.rf.74b204ede0834a099f56a41742941027.jpg: 416x640 2 foxs, 21.7ms
# Speed: 2.6ms preprocess, 21.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# array([[[240, 239, 243],
#         [249, 248, 252],
#         [247, 248, 252],
#         ...,
#         [238, 240, 251],
#         [245, 246, 255],
#         [245, 246, 255]],
#
#        [[ 51,  50,  54],
#         [ 68,  69,  73],
#         [ 85,  86,  90],
#         ...,
#         [ 91,  93, 104],
#         [115, 116, 126],
#         [115, 116, 126]],
#
#        [[ 53,  53,  59],
#         [ 70,  73,  78],
#         [ 85,  88,  93],
#         ...,
#         [ 87,  91, 102],
#         [125, 127, 137],
#         [125, 127, 137]],
#
#        ...,
#
#        [[104,  31,  17],
#         [104,  31,  17],
#         [165, 123, 119],
#         ...,
#         [243, 235, 222],
#         [237, 229, 216],
#         [237, 229, 216]],
#
# ...
